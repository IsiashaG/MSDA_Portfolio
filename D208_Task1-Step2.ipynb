# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn

from scipy import stats
from scipy.stats import f_oneway
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
file_path = "/Users/igmark/Desktop/WGU Data Files/new_data_col.csv"
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    Children  Tenure  Yearly_equip_failure  MonthlyCharge  Age  Income  Email  \
# 0         0      10                     0             50   25   50000      2
# 1         1      20                     1             75   30   60000      4
# 2         0      30                     0            100   35   70000      6
# 3         1      40                     2            125   40   80000      8
# 4         2      50                     1            150   45   90000     10
#
#    Contacts  Outage_sec_perweek  Population  ...  Z_Score_Income  \
# 0         1                  10         100  ...       -1.264911
# 1         3                  20         200  ...       -0.632456
# 2         5                  30         300  ...        0.000000
# 3         7                  40         400  ...        0.632456
# 4         9                  50         500  ...        1.264911
#
#    Z_Score_Email  Z_Score_Contacts  Z_Score_Outage_sec_perweek  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 30 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Children                      5 non-null      int64
#  1   Tenure                        5 non-null      int64
#  2   Yearly_equip_failure          5 non-null      int64
#  3   MonthlyCharge                 5 non-null      int64
#  4   Age                           5 non-null      int64
#  5   Income                        5 non-null      int64
#  6   Email                         5 non-null      int64
#  7   Contacts                      5 non-null      int64
#  8   Outage_sec_perweek            5 non-null      int64
#  9   Population                    5 non-null      int64
#  10  Bandwidth_GB_Year             5 non-null      int64
#  11  Phone                         5 non-null      int64
#  12  TechSupport                   5 non-null      int64
# ...

# %% [markdown]
# # Linear Regression

# %%
import statsmodels.api as sm

# Set up your independent and dependent variables
X = df[['Z_Score_Children', 'Z_Score_Tenure', 'Z_Score_Yearly_equip_failure', 'Z_Score_MonthlyCharge', 'Z_Score_Age', 
        'Z_Score_Income', 'Z_Score_Email','Z_Score_Contacts', 'Z_Score_Outage_sec_perweek', 
        'Z_Score_Population', 'Z_Score_Phone', 'Z_Score_TechSupport', 'Techie', 'Gender_F', 'Gender_M']]
y = df['Z_Score_Bandwidth_GB_Year']

# Add a constant term to the independent variable matrix
X = sm.add_constant(X)

# Fit an OLS regression model on the data
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())
# Out:
#                                 OLS Regression Results
# ...
# Dep. Variable:     Z_Score_Bandwidth_GB_Year   R-squared:                       1.000
# Model:                                   OLS   Adj. R-squared:                    nan
# Method:                        Least Squares   F-statistic:                       nan
# Date:                       Sat, 25 Feb 2023   Prob (F-statistic):                nan
# Time:                               09:12:48   Log-Likelihood:                 171.33
# No. Observations:                          5   AIC:                            -332.7
# Df Residuals:                              0   BIC:                            -334.6
# Df Model:                                  4
# Covariance Type:                   nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Reduced Model with VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Define the independent and dependent variables
X = df[['Z_Score_Children', 'Z_Score_Tenure', 'Z_Score_Yearly_equip_failure', 'Z_Score_MonthlyCharge', 'Z_Score_Age', 
        'Z_Score_Income', 'Z_Score_Email','Z_Score_Contacts', 'Z_Score_Outage_sec_perweek', 
        'Z_Score_Population', 'Z_Score_Phone', 'Z_Score_TechSupport', 'Techie', 'Gender_F', 'Gender_M']]
y = df['Z_Score_Bandwidth_GB_Year']

# Calculate VIFs for each independent variable
vifs = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Print the VIFs for each variable
for i, col in enumerate(X.columns):
    print(f'{col}: {vifs[i]:.2f}')

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Fit the OLS model
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())
# Out:
# Z_Score_Children: 2.80
# Z_Score_Tenure: inf
# Z_Score_Yearly_equip_failure: 11.20
# Z_Score_MonthlyCharge: inf
# Z_Score_Age: inf
# Z_Score_Income: inf
# Z_Score_Email: inf
# Z_Score_Contacts: inf
# Z_Score_Outage_sec_perweek: inf
# Z_Score_Population: inf
# Z_Score_Phone: inf
# Z_Score_TechSupport: inf
# Techie: inf
# Gender_F: inf
# Gender_M: inf
#                                 OLS Regression Results
# ...
# Dep. Variable:     Z_Score_Bandwidth_GB_Year   R-squared:                       1.000
# Model:                                   OLS   Adj. R-squared:                    nan
# Method:                        Least Squares   F-statistic:                       nan
# Date:                       Sat, 25 Feb 2023   Prob (F-statistic):                nan
# Time:                               09:13:22   Log-Likelihood:                 171.33
# No. Observations:                          5   AIC:                            -332.7
# ...

# %% [markdown]
# # Removal of Yearly_equip_failure (11.20)

# %%
# Define the independent and dependent variables
X = df[['Z_Score_Children', 'Z_Score_Tenure', 'Z_Score_MonthlyCharge', 'Z_Score_Age', 
        'Z_Score_Income', 'Z_Score_Email','Z_Score_Contacts', 'Z_Score_Outage_sec_perweek', 
        'Z_Score_Population', 'Z_Score_Phone', 'Z_Score_TechSupport', 'Techie', 'Gender_F', 'Gender_M']]
y = df['Z_Score_Bandwidth_GB_Year']

# Calculate VIFs for each independent variable
vifs = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Print the VIFs for each variable
for i, col in enumerate(X.columns):
    print(f'{col}: {vifs[i]:.2f}')

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Fit the OLS model
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())
# Out:
# Z_Score_Children: 2.62
# Z_Score_Tenure: inf
# Z_Score_MonthlyCharge: inf
# Z_Score_Age: inf
# Z_Score_Income: inf
# Z_Score_Email: inf
# Z_Score_Contacts: inf
# Z_Score_Outage_sec_perweek: inf
# Z_Score_Population: inf
# Z_Score_Phone: inf
# Z_Score_TechSupport: inf
# Techie: inf
# Gender_F: inf
# Gender_M: inf
#                                 OLS Regression Results
# ...
# Dep. Variable:     Z_Score_Bandwidth_GB_Year   R-squared:                       1.000
# Model:                                   OLS   Adj. R-squared:                  1.000
# Method:                        Least Squares   F-statistic:                 7.713e+30
# Date:                       Sat, 25 Feb 2023   Prob (F-statistic):           2.65e-16
# Time:                               09:17:29   Log-Likelihood:                 174.01
# No. Observations:                          5   AIC:                            -340.0
# Df Residuals:                              1   BIC:                            -341.6
# ...
